# %% [markdown]
# # Aula de markdown
# ## Aula de markdown
# ### <b>Aula <b> de markdown

# %%
a = "Hello World!"
a
# Out:
# 'Hello World!'

# %%
print(a)
# Out:
# Hello World!

# %%
#soma
a = 3
b = 5
c = "2"

# %%
a + b
# Out:
# 8

# %%
b + c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 b + c
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(b,c)
# Out:
# 5 2

# %%
5//2
# Out:
# 2

# %%
5%2
# Out:
# 1

# %%
num = 0
def par ():
    num = int(input("Digite um número natural: "))
    if num%2 == 0:
        print(num, "é par")
    else:
        print(num, "é ímpar")

# %%
par()
# Out:
# Digite um número natural:  54
# 54 é par

# %%
par ()
# Out:
# Digite um número natural:  57
# 57 é ímpar

# %%
def fipe ():
    ano = int(input("Digite o ano de nascimento: "))
    if ano <= 1990:
        print("Parabéns, sua fipe está alta!")
    else:
        print("Ainda tem muito chão para percorrer.")

# %%
fipe()
# Out:
# Digite o ano de nascimento:  1999
# Ainda tem muito chão para percorrer.
